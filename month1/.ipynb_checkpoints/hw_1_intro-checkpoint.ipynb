# %%
import torch
from torch import utils
from torchvision import datasets, transforms

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### 1

# %%
from salt import salt
salt('Головенков Евгений')
# Out:
# 'e36aaa4e1429381b'

# %% [markdown]
# #### 2

# %%
path = '.mnist'

# %%
train_data = datasets.MNIST(path, train=True, download=True)
test_data  = datasets.MNIST(path, train=False, download=True)

train_mean = train_data.train_data.float().mean()/255
train_std  = train_data.train_data.float().std()/255

print(train_mean)
print(train_std)
# Out:
# ...
# Processing...
# Done!
# 0.1306604762738429
# 0.30810780717887876

# %%
normalize_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((train_mean,), (train_std,)),
           ])

# %%
train_data = datasets.MNIST(path, train=True, download=True, transform=normalize_transform)
test_data = datasets.MNIST(path, train=False, download=True, transform=normalize_transform)

# %%
train_data.train_data.float().std()
# Out:
# 78.56749083061408

# %%
test_data[0][0]
# Out:
# tensor([[[-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241],
#          [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241],
#          [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#           -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241],
#          [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
# ...
